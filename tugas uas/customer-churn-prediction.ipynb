# %% [markdown]
# **<center> <span style="color:#0F52BA;font-family:serif; font-size:34px;"> PREDIKSI PERUBAHAN PELANGGAN 📈</span> </center>**

# %% [markdown]
# <style>
# img
# {
#     display:block;
#     float:none;
#     margin-left:auto;
#     margin-right:auto;
#     width:80%;
# }
# </style>

# %% [markdown]
# <center><span style="font-family:Palatino; font-size:22px;"><i> Tahukah Anda bahwa menarik pelanggan baru membutuhkan biaya <span style="color:#DC143C;">lima kali</span> lebih banyak, sama seperti mempertahankan pelanggan yang sudah ada?</i></span> </center>

# %% [markdown]
# ![churn 1.png](attachment:7a47ebdd-9f53-4bf0-bc99-b56b8050a874.png)

# %% [markdown]
# # <span style="font-family:serif; font-size:28px;"> Content</span>
#
# 1. [Introduction](#1)
#     * [Apa itu Pelanggan Churn?](#2)
#     * [Bagaimana mengurangi pelanggan yang churn/pergi?](#3)
#     * [Objectives](#4)
# 2. [Loading libraries and data](#5)
# 3. [Undertanding the data](#6)
# 4. [Visualize missing values](#7)
# 5. [Data Manipulation](#8)
# 6. [Data Visualization](#9)
# 7. [Data Preprocessing](#10)
#    * [Standardizing numeric attributes](#111)
# 8. [Machine Learning Model Evaluations and Predictions](#11)
#    * [KNN](#101)
#    * [SVC](#102)
#    * [Random Forest](#103)
#    * [Logistic Regression](#104)
#    * [Decision Tree Classifier](#105)
#    * [AdaBoost Classifier](#106)
#    * [Gradient Boosting Classifier](#107)
#    * [Voting Classifier](#108)

# %% [markdown]
# <a id = "1" ></a>
# # <span style="font-family:serif; font-size:28px;"> 1. Introduction</span>
# <a id = "introduction" ></a>

# %% [markdown]
# <a id = "2" ></a>
# #### <b>Apa itu Churn Pelanggan?</b>
# <span style="font-size:16px;">Churn pelanggan didefinisikan sebagai ketika pelanggan atau pelanggan berhenti berbisnis dengan suatu perusahaan atau layanan.</span>
#
# <span style="font-size:16px;">Pelanggan di industri telekomunikasi dapat memilih dari berbagai penyedia layanan dan secara aktif beralih dari satu penyedia ke penyedia lainnya. Bisnis telekomunikasi memiliki tingkat churn tahunan sebesar 15-25 persen di pasar yang sangat kompetitif ini.</span>
#
# <span style="font-size:16px;">Pertahanan pelanggan yang individualisasi sulit dilakukan karena kebanyakan perusahaan memiliki banyak pelanggan dan tidak dapat menghabiskan banyak waktu untuk setiap pelanggan. Biaya akan terlalu besar, melebihi pendapatan tambahan yang diperoleh. Namun, jika suatu perusahaan dapat memprediksi pelanggan mana yang kemungkinan besar akan meninggalkan di masa depan, perusahaan dapat fokus pada upaya retensi pelanggan hanya pada pelanggan "berisiko tinggi" ini. Tujuan utamanya adalah untuk memperluas jangkauan dan mendapatkan lebih banyak loyalitas pelanggan. Inti kesuksesan di pasar ini terletak pada pelanggan itu sendiri.</span>
#
# <span style="font-size:16px;">Churn pelanggan adalah metrik yang penting karena lebih murah untuk mempertahankan pelanggan yang ada daripada mengakuisisi pelanggan baru.</span>
#
# <a id="churn"></a>
# <a id = "3" ></a>
#
# <span style="font-size:16px;"><b>Untuk mengurangi churn pelanggan, perusahaan telekomunikasi perlu memprediksi pelanggan mana yang berisiko tinggi untuk churn.</b></span>
#
# <span style="font-size:16px;">Untuk mendeteksi tanda-tanda awal churn potensial, pertama-tama harus dikembangkan pandangan menyeluruh tentang pelanggan dan interaksi mereka di berbagai saluran, termasuk kunjungan toko/cabang, riwayat pembelian produk, panggilan layanan pelanggan, transaksi berbasis web, dan interaksi media sosial, hanya beberapa di antaranya.</span>
#
# <span style="font-size:16px;">Dengan mengatasi churn, perusahaan-perusahaan ini tidak hanya dapat mempertahankan posisi pasar mereka, tetapi juga tumbuh dan berkembang. Semakin banyak pelanggan yang mereka miliki dalam jaringan mereka, semakin rendah biaya inisiasi dan semakin besar keuntungannya. Oleh karena itu, fokus utama perusahaan untuk mencapai kesuksesan adalah mengurangi perpindahan pelanggan dan mengimplementasikan strategi retensi yang efektif.</span>
# <a id="reduce"></a>
#
# <a id = "4" ></a>
# #### <b>Objektif</b>
# Saya akan menjelajahi data dan mencoba menjawab beberapa pertanyaan seperti:
# * Berapa persen Pelanggan Churn dan pelanggan yang tetap menggunakan layanan aktif?
# * Apakah ada pola pada Pelanggan Churn berdasarkan jenis kelamin?
# * Apakah ada pola/preferensi pada Pelanggan Churn berdasarkan jenis layanan yang diberikan?
# * Jenis layanan mana
#
#  yang paling menguntungkan?
# * Fitur dan layanan apa yang paling menguntungkan?
# * Banyak pertanyaan lain yang akan muncul selama analisis
# <a id="objective"></a>

# %% [markdown]
# ___

# %% [markdown]
# <a id = "5" ></a>
# # <span style="font-family:serif; font-size:28px;"> 2. Loading libraries and data</span>
# <a id="loading"></a>

# %%
# Library pandas untuk manipulasi dan analisis data
import pandas as pd

# Library numpy untuk operasi numerik pada data
import numpy as np

# Library missingno untuk visualisasi data yang hilang
import missingno as msno

# Library matplotlib untuk visualisasi data secara umum
import matplotlib.pyplot as plt

# Library seaborn untuk visualisasi data dengan tampilan yang lebih menarik
import seaborn as sns

# Library plotly untuk visualisasi interaktif
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')  # Mengabaikan pesan peringatan
# Out:
# /Users/choco/opt/anaconda3/envs/amd_gpu/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Import library yang diperlukan untuk preprocessing dan evaluasi model

# Mengimport StandardScaler untuk melakukan normalisasi data
from sklearn.preprocessing import StandardScaler

# Mengimport LabelEncoder untuk melakukan label encoding pada data kategorikal
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# Mengimport PCA untuk melakukan reduksi dimensi data
from sklearn.decomposition import PCA

# Mengimport stats dari scipy untuk melakukan normalisasi data dengan menghilangkan outlier
from scipy import stats

# Mengimport beberapa algoritma klasifikasi yang akan digunakan
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
# from xgboost import XGBClassifier
# from catboost import CatBoostClassifier

# Mengimport train_test_split untuk membagi data menjadi set pelatihan dan pengujian
from sklearn.model_selection import train_test_split

# Mengimport beberapa metrik evaluasi yang akan digunakan
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import recall_score, confusion_matrix, precision_score, f1_score, accuracy_score, classification_report

# %%
#loading data
df = pd.read_csv('dataset/archive (10)/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %% [markdown]
# ___

# %% [markdown]
# <a id = "6" ></a>
# # <span style="font-family:serif; font-size:28px;"> 3. Undertanding the data</span>
# <a id = "Undertanding the data" ></a>

# %% [markdown]
# Setiap baris mewakili pelanggan, setiap kolom berisi atribut pelanggan yang dijelaskan pada kolom Metadata.

# %%
# Menampilkan 5 baris pertama dari DataFrame
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# **Kumpulan data mencakup informasi tentang:**
#
# **Pelanggan yang keluar dalam satu bulan terakhir** - kolom ini disebut Churn.
#
# * **Layanan yang telah didaftarkan oleh setiap pelanggan** - telepon, beberapa saluran, internet, keamanan online, pencadangan online, perlindungan perangkat, dukungan teknis, dan streaming TV dan film
#
# * **Informasi akun pelanggan** - berapa lama mereka telah menjadi pelanggan, kontrak, metode pembayaran, penagihan tanpa kertas, tagihan bulanan, dan total tagihan
#
# * **Informasi demografis tentang pelanggan** - jenis kelamin, rentang usia, dan apakah mereka memiliki pasangan dan tanggungan

# %%
# Menampilkan dimensi DataFrame (jumlah baris, jumlah kolom)
df.shape
# Out:
# (7043, 21)

# %%
# Menampilkan informasi tentang DataFrame termasuk tipe data kolom dan jumlah nilai non-null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Menampilkan nama-nama kolom dalam DataFrame
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Menampilkan tipe data dari setiap kolom dalam DataFrame
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# * Target yang akan kami gunakan untuk memandu eksplorasi adalah **Churn**

# %% [markdown]
# ***

# %% [markdown]
# <a id = "7" ></a>
# # <span style="font-family:serif; font-size:28px;"> 4. Visualize missing values </span>
# <a id = "missingvalue" ></a>

# %%
# Visualize missing values as a matrix
msno.matrix(df);

# %% [markdown]
# > Dengan menggunakan matriks ini, kita dapat dengan cepat menemukan pola kehilangan dalam set data.
# * Dari visualisasi di atas, kita dapat mengamati bahwa tidak ada pola khusus yang menonjol. Bahkan tidak ada data yang hilang.

# %% [markdown]
# ***

# %% [markdown]
# <a id = "8" ></a>
# # <span style="font-family:serif; font-size:28px;"> 5. Data Manipulation </span>
# <a id = "8" ></a>

# %%
# Menghapus kolom 'customerID' dari DataFrame
df = df.drop(['customerID'], axis=1)

# Menampilkan 5 baris pertama dari DataFrame setelah penghapusan kolom
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# * Pada deep analisis, kita dapat menemukan beberapa missing tidak langsung dalam data kita (yang dapat berupa spasi kosong).

# %%
# Mengubah kolom 'TotalCharges' menjadi tipe data numerik
df['TotalCharges'] = pd.to_numeric(df.TotalCharges, errors='coerce')

# Menghitung jumlah nilai null (missing values) pada setiap kolom dataframe
null_counts = df.isnull().sum()

# %% [markdown]
# * Di sini kita melihat bahwa TotalCharges memiliki 11 nilai yang hilang. Mari kita periksa data ini.

# %%
# Mengidentifikasi baris-baris dengan nilai NaN pada kolom 'TotalCharges'
nan_rows = df[np.isnan(df['TotalCharges'])]

# %% [markdown]
# * Dapat juga dicatat bahwa kolom Tenor adalah 0 untuk entri;entri ini meskipun kolom MonthlyCharges tidak kosong.
#
# Mari kita lihat apakah ada nilai 0 lainnya di kolom tenor.

# %%
# Mengambil indeks baris di mana nilai kolom 'tenure' sama dengan 0
df[df['tenure'] == 0].index
# Out:
# Int64Index([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754], dtype='int64')

# %% [markdown]
# * Tidak ada nilai yang hilang di kolom Tenure.
#
# Mari kita hapus baris dengan nilai yang hilang di kolom Tenure karena hanya ada 11 baris dan menghapusnya tidak akan mempengaruhi data.

# %%
# Menghapus baris dengan nilai 'tenure' sama dengan 0 dari DataFrame
df.drop(labels=df[df['tenure'] == 0].index, axis=0, inplace=True)

# Menampilkan indeks baris dengan nilai 'tenure' sama dengan 0
print(df[df['tenure'] == 0].index)
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# > Untuk mengatasi masalah nilai yang hilang pada kolom TotalCharges,akan mengisinya dengan mean dari nilai TotalCharges.

# %%
# Mengisi nilai yang hilang pada kolom "TotalCharges" dengan nilai rata-rata kolom tersebut
df.fillna(df["TotalCharges"].mean())
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
# Menghitung jumlah nilai yang hilang (missing values) dalam setiap kolom DataFrame
# dan menampilkan hasilnya
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Mengubah nilai pada kolom "SeniorCitizen" menjadi "No" dan "Yes"
df["SeniorCitizen"] = df["SeniorCitizen"].map({0: "No", 1: "Yes"})

# Menampilkan lima baris pertama dari dataframe setelah perubahan nilai pada kolom "SeniorCitizen"
df.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            No     Yes         No       1           No
# 1    Male            No      No         No      34          Yes
# 2    Male            No      No         No       2          Yes
# 3    Male            No      No         No      45           No
# 4  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# Menampilkan deskripsi statistik dari kolom "InternetService"
df["InternetService"].describe(include=['object', 'bool'])
# Out:
# count            7032
# unique              3
# top       Fiber optic
# freq             3096
# Name: InternetService, dtype: object

# %%
# Mendefinisikan kolom-kolom numerik yang ingin dianalisis
numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

# Menggunakan metode describe() untuk mendapatkan ringkasan statistik dari kolom-kolom numerik
df[numerical_cols].describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7032.000000     7032.000000   7032.000000
# mean     32.421786       64.798208   2283.300441
# std      24.545260       30.085974   2266.771362
# min       1.000000       18.250000     18.800000
# 25%       9.000000       35.587500    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.862500   3794.737500
# max      72.000000      118.750000   8684.800000

# %% [markdown]
# ___

# %% [markdown]
# <a id = "9" ></a>
# # <span style="font-family:serif; font-size:28px;"> 6. Data Visualization </span>
# <a id = "datavisualization" ></a>

# %%
g_labels = ['Male', 'Female']
c_labels = ['No', 'Yes']
# Membuat subplot: menggunakan tipe 'domain' untuk subplot Pie
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])

# Menambahkan data Pie untuk kategori 'Gender'
fig.add_trace(go.Pie(labels=g_labels, values=df['gender'].value_counts(), name="Gender"),
              1, 1)

# Menambahkan data Pie untuk kategori 'Churn'
fig.add_trace(go.Pie(labels=c_labels, values=df['Churn'].value_counts(), name="Churn"),
              1, 2)

# Menggunakan 'hole' untuk membuat tampilan donat pada pie chart
fig.update_traces(hole=.4, hoverinfo="label+percent+name", textfont_size=16)

fig.update_layout(
    title_text="Gender and Churn Distributions",
    # Menambahkan anotasi di tengah pie chart
    annotations=[dict(text='Gender', x=0.16, y=0.5, font_size=20, showarrow=False),
                 dict(text='Churn', x=0.84, y=0.5, font_size=20, showarrow=False)])
fig.show()

# %% [markdown]
# * 26,6% pelanggan beralih ke perusahaan lain.
# * Pelanggan terdiri dari 49,5% perempuan dan 50,5% laki-laki.

# %%
# Menghitung jumlah pengguna yang tidak berpindah (Churn = "No") berdasarkan jenis kelamin (gender)
df["Churn"][df["Churn"]=="No"].groupby(by=df["gender"]).count()
# Out:
# gender
# Female    2544
# Male      2619
# Name: Churn, dtype: int64

# %%
# Menghitung jumlah churn (Churn == "Yes") berdasarkan gender
df["Churn"][df["Churn"]=="Yes"].groupby(by=df["gender"]).count()
# Out:
# gender
# Female    939
# Male      930
# Name: Churn, dtype: int64

# %%
# Menentukan ukuran gambar plot
plt.figure(figsize=(6, 6))

# Data untuk pie chart Churn
labels = ["Churn: Yes", "Churn: No"]
values = [1869, 5163]

# Data untuk pie chart Gender
labels_gender = ["F", "M", "F", "M"]
sizes_gender = [939, 930, 2544, 2619]

# Warna untuk pie chart Churn
colors = ['#ff6666', '#66b3ff']

# Warna untuk pie chart Gender
colors_gender = ['#c2c2f0', '#ffb3e6', '#c2c2f0', '#ffb3e6']

# Pengaturan pecahan dan jarak label pada pie chart Churn
explode = (0.3, 0.3)

# Pengaturan pecahan pada pie chart Gender
explode_gender = (0.1, 0.1, 0.1, 0.1)

# Pengaturan properti teks pada label
textprops = {"fontsize": 15}

# Plot pie chart Churn
plt.pie(values, labels=labels, autopct='%1.1f%%', pctdistance=1.08, labeldistance=0.8,
        colors=colors, startangle=90, frame=True, explode=explode, radius=10, textprops=textprops, counterclock=True)

# Plot pie chart Gender
plt.pie(sizes_gender, labels=labels_gender, colors=colors_gender, startangle=90,
        explode=explode_gender, radius=7, textprops=textprops, counterclock=True)

# Menggambar lingkaran tengah
centre_circle = plt.Circle((0, 0), 5, color='black', fc='white', linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Judul plot
plt.title('Churn Distribution w.r.t Gender: Male(M), Female(F)', fontsize=15, y=1.1)

# Menampilkan plot
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# * Terdapat perbedaan yang dapat diabaikan dalam persentase/ jumlah pelanggan yang berpindah penyedia layanan. Kedua jenis kelamin berperilaku dengan cara yang sama dalam hal berpindah ke penyedia layanan/perusahaan lain.

# %%
# Membuat histogram menggunakan plotly express
fig = px.histogram(df, x="Churn", color="Contract", barmode="group", title="<b>Distribusi Kontrak Pelanggan<b>")

# Mengatur lebar, tinggi, dan jarak antar batang histogram
fig.update_layout(width=700, height=500, bargap=0.1)

# Menampilkan histogram
fig.show()

# %% [markdown]
# * Sekitar 75% pelanggan dengan Kontrak Bulanan memilih untuk pindah dibandingkan dengan 13% pelanggan dengan Kontrak Satu Tahun dan 3% dengan Kontrak Dua Tahun

# %%
# Mendapatkan unique labels dari kolom 'PaymentMethod'
labels = df['PaymentMethod'].unique()

# Menghitung jumlah kemunculan setiap nilai dalam kolom 'PaymentMethod'
values = df['PaymentMethod'].value_counts()

# Membuat objek Figure untuk membuat pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.3)])

# Mengupdate layout untuk menambahkan judul pada pie chart
fig.update_layout(title_text="<b>Distribusi Metode Pembayaran</b>")

# Menampilkan pie chart
fig.show()

# %%
# Membuat histogram menggunakan Plotly Express
fig = px.histogram(df, x="Churn", color="PaymentMethod", title="<b>Distribusi Metode Pembayaran Pelanggan terhadap Churn</b>")

# Mengatur lebar, tinggi, dan jarak antara batang histogram
fig.update_layout(width=700, height=500, bargap=0.1)

# Menampilkan histogram
fig.show()

# %% [markdown]
# * pelanggan utama yang pindah menggunakan Cek Elektronik sebagai metode pembayaran.
# * pelanggan yang memilih transfer otomatis Kartu Kredit atau Transfer Otomatis Bank dan Cek Pos sebagai Metode Pembayaran lebih kecil kemungkinannya untuk pindah.

# %% [markdown]
# ___

# %% [markdown]
# <a id = "10" ></a>
# # <span style="font-family:serif; font-size:28px;"> 7. Data Preprocessing</span>
# <a id = "datapreprocessing" ></a>

# %% [markdown]
# <a id = "1111" ></a>
# #### **Splitting the data into train and test sets**
# <a id = "Split" ></a>

# %%
def object_to_int(dataframe_series):
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
df = df.apply(lambda x: object_to_int(x))
df.head(20)
# Out:
#     gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0        0              0        1           0       1             0
# 1        1              0        0           0      34             1
# 2        1              0        0           0       2             1
# 3        1              0        0           0      45             0
# 4        0              0        0           0       2             1
# 5        0              0        0           0       8             1
# 6        1              0        0           1      22             1
# 7        0              0        0           0      10             0
# 8        0              0        1           0      28             1
# 9        1              0        0           1      62             1
# 10       1              0        1           1      13             1
# 11       1              0        0           0      16             1
# 12       1              0        1           0      58             1
# ...

# %%
plt.figure(figsize=(14,7))
df.corr()['Churn'].sort_values(ascending = False)
# Out:
# Churn               1.000000
# MonthlyCharges      0.192858
# PaperlessBilling    0.191454
# SeniorCitizen       0.150541
# PaymentMethod       0.107852
# MultipleLines       0.038043
# PhoneService        0.011691
# gender             -0.008545
# StreamingTV        -0.036303
# StreamingMovies    -0.038802
# InternetService    -0.047097
# Partner            -0.149982
# Dependents         -0.163128
# DeviceProtection   -0.177883
# OnlineBackup       -0.195290
# TotalCharges       -0.199484
# TechSupport        -0.282232
# OnlineSecurity     -0.289050
# tenure             -0.354049
# Contract           -0.396150
# Name: Churn, dtype: float64

# %%
# Menghitung korelasi antara fitur-fitur dengan kolom 'Churn' dan mengurutkannya secara menurun
correlation = df.corr()['Churn'].sort_values(ascending=False)

# Mengambil 4 fitur dengan korelasi tertinggi kecuali 'Churn'
top_4_features = correlation[1:5].index.tolist()

# Menampilkan fitur-fitur yang akan digunakan untuk training model
print("Fitur-fitur untuk training model:")
print(top_4_features)
# Out:
# Fitur-fitur untuk training model:
# ['MonthlyCharges', 'PaperlessBilling', 'SeniorCitizen', 'PaymentMethod']

# %%
# Mengambil fitur-fitur dari dataset ke dalam variabel X
X = df[top_4_features]

# Mengambil target (label) dari dataset ke dalam variabel y
y = df['Churn'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)

# %%
def distplot(feature, frame, color='r'):
    plt.figure(figsize=(8,3))
    plt.title("Distribution for {}".format(feature))
    ax = sns.distplot(frame[feature], color= color)

# %%
num_cols = ['MonthlyCharges', 'PaperlessBilling', 'SeniorCitizen', 'PaymentMethod']
for feat in num_cols: distplot(feat, df)

# %%
print(X_train, X_test)
# Out:
#       MonthlyCharges  PaperlessBilling  SeniorCitizen  PaymentMethod
# 3946           58.50                 0              0              3
# 3394           61.55                 0              0              2
# 1635           69.95                 1              0              2
# 4088           73.60                 0              0              2
# 1886           60.40                 1              0              0
# ...              ...               ...            ...            ...
# 3778           50.40                 0              0              0
# 5199          111.50                 1              0              2
# 5235           81.15                 1              0              2
# 5399           19.75                 0              0              0
# 862            73.65                 1              1              2
#
# [4922 rows x 4 columns]       MonthlyCharges  PaperlessBilling  SeniorCitizen  PaymentMethod
# ...

# %% [markdown]
# <a id = "11" ></a>
# # <span style="font-family:serif; font-size:28px;"> 8. Machine Learning Model Evaluations and Predictions</span>
# <a id = "modelprediction" ></a>

# %% [markdown]
# ![AI-Workbench-Predict-propensity-churn-notebook.png](attachment:8fc66a4b-838f-401e-bf6b-4577d1f313ec.png)

# %% [markdown]
# <a id = "101" ></a>
# #### <b> KNN</b>
# <a id = "knn" ></a>

# %%
import pickle
from sklearn.neighbors import KNeighborsClassifier

# Membuat objek model KNN
knn_model = KNeighborsClassifier(n_neighbors=11)

# Melatih model dengan data latih yang telah di-oversampling
knn_model.fit(X_train, y_train)

# Memprediksi target menggunakan data uji
predicted_y = knn_model.predict(X_test)

# Menghitung akurasi model
accuracy_knn = accuracy_score(y_test, predicted_y)

print("KNN accuracy:", accuracy_knn)

# Simpan model ke dalam file pkl
with open('knn_model.pkl', 'wb') as file:
    pickle.dump(knn_model, file)
# Out:
# KNN accuracy: 0.7464454976303317

# %%
import pickle

# Load model dari file pkl
with open('knn_model.pkl', 'rb') as file:
    knn_model = pickle.load(file)

# Membuat input data baru untuk pengujian
new_data = [[58.50, 0, 0, 3],    # Contoh data 1
            [61.55, 0, 0, 2],    # Contoh data 2
            [69.95, 1, 0, 2],    # Contoh data 3
            [73.60, 0, 0, 2],    # Contoh data 4
            [70.25, 1, 1, 0]]    # Contoh data 5 (dengan prediksi 1)

# Melakukan prediksi menggunakan model KNN
predictions = knn_model.predict(new_data)

# Menampilkan hasil prediksi
for data, prediction in zip(new_data, predictions):
    print("Input Data:", data)
    print("Prediction:", prediction)
    print()
# Out:
# Input Data: [58.5, 0, 0, 3]
# Prediction: 0
#
# Input Data: [61.55, 0, 0, 2]
# Prediction: 0
#
# Input Data: [69.95, 1, 0, 2]
# Prediction: 0
#
# Input Data: [73.6, 0, 0, 2]
# Prediction: 0
#
# Input Data: [70.25, 1, 1, 0]
# Prediction: 1

# %%
print(classification_report(y_test, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.84      1549
#            1       0.53      0.37      0.44       561
#
#     accuracy                           0.75      2110
#    macro avg       0.66      0.63      0.64      2110
# weighted avg       0.73      0.75      0.73      2110

# %% [markdown]
# Dari matriks kebingungan kita dapat melihat hal tersebut:
# Terdapat total 1400+149 = 1549 nilai non-churn aktual dan algoritme memprediksi 1400 di antaranya sebagai non churn dan 149 di antaranya sebagai churn.
# Sementara ada 237+324=561 nilai churn yang sebenarnya dan algoritma memprediksi 237 di antaranya sebagai nilai non churn dan 324 di antaranya sebagai nilai churn.

# %% [markdown]
# Perpindahan pelanggan jelas berdampak buruk bagi profitabilitas perusahaan. Berbagai strategi dapat diterapkan untuk menghilangkan customer churn. Cara terbaik untuk menghindari customer churn adalah perusahaan harus benar-benar mengenal pelanggannya. Hal ini termasuk mengidentifikasi pelanggan yang berisiko berpindah dan berupaya meningkatkan kepuasan mereka. Meningkatkan layanan pelanggan, tentu saja, merupakan prioritas utama untuk mengatasi masalah ini. Membangun loyalitas pelanggan melalui pengalaman yang relevan dan layanan khusus adalah strategi lain untuk mengurangi perpindahan pelanggan. Beberapa perusahaan mensurvei pelanggan yang telah berpindah untuk memahami alasan mereka meninggalkan perusahaan agar dapat mengadopsi pendekatan proaktif untuk menghindari perpindahan pelanggan di masa depan.

# %% [markdown]
# <a id = "102" ></a>
# #### <b>SVC</b>
# <a id = "svc" ></a>

# %%
svc_model = SVC(random_state=1)  # Inisialisasi model Support Vector Machine dengan random_state=1 untuk hasil yang dapat direproduksi
svc_model.fit(X_train, y_train)  # Melatih model dengan data latih
predict_y = svc_model.predict(X_test)  # Melakukan prediksi pada data uji
accuracy_svc = svc_model.score(X_test, y_test)  # Menghitung akurasi model pada data uji
print("SVM accuracy is:", accuracy_svc)  # Menampilkan akurasi model SVM
# Out:
# SVM accuracy is: 0.7341232227488151

# %%
print(classification_report(y_test, predict_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      1.00      0.85      1549
#            1       0.00      0.00      0.00       561
#
#     accuracy                           0.73      2110
#    macro avg       0.37      0.50      0.42      2110
# weighted avg       0.54      0.73      0.62      2110

# %% [markdown]
# <a id = "103" ></a>
# #### <b> Random Forest</b>
# <a id = "rf" ></a>

# %%
# Membuat objek model Random Forest Classifier dengan parameter yang telah ditentukan
model_rf = RandomForestClassifier(n_estimators=500 , oob_score = True, n_jobs = -1,
                                  random_state =50, max_features = "auto",
                                  max_leaf_nodes = 30)

# Melatih model menggunakan data latih
model_rf.fit(X_train, y_train)

# Melakukan prediksi menggunakan data uji
prediction_test = model_rf.predict(X_test)

# Menghitung akurasi dengan membandingkan prediksi dengan nilai sebenarnya
accuracy = metrics.accuracy_score(y_test, prediction_test)
print(accuracy)
# Out:
# 0.7587677725118483

# %%
print(classification_report(y_test, prediction_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85      1549
#            1       0.58      0.33      0.42       561
#
#     accuracy                           0.76      2110
#    macro avg       0.69      0.62      0.64      2110
# weighted avg       0.73      0.76      0.73      2110

# %%
plt.figure(figsize=(4,3))
sns.heatmap(confusion_matrix(y_test, prediction_test),
                annot=True,fmt = "d",linecolor="k",linewidths=3)
    
plt.title(" RANDOM FOREST CONFUSION MATRIX",fontsize=14)
plt.show()

# %%
y_rfpred_prob = model_rf.predict_proba(X_test)[:,1]
fpr_rf, tpr_rf, thresholds = roc_curve(y_test, y_rfpred_prob)
plt.plot([0, 1], [0, 1], 'k--' )
plt.plot(fpr_rf, tpr_rf, label='Random Forest',color = "r")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC Curve',fontsize=16)
plt.show();

# %% [markdown]
# <a id = "104" ></a>
# #### <b>Logistic Regression</b>
# <a id = "lr" ></a>

# %%
# tanpa over/under sampling
# Membuat objek model Logistic Regression
lr_model = LogisticRegression()

# Melatih model menggunakan data latih
lr_model.fit(X_train, y_train)

# Menghitung akurasi model menggunakan data uji
accuracy_lr = lr_model.score(X_test, y_test)

# Menampilkan hasil akurasi
print("Logistic Regression accuracy is:", accuracy_lr)
# Out:
# Logistic Regression accuracy is: 0.7317535545023697

# %%
lr_pred= lr_model.predict(X_test)
report = classification_report(y_test,lr_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84      1549
#            1       0.48      0.11      0.18       561
#
#     accuracy                           0.73      2110
#    macro avg       0.61      0.53      0.51      2110
# weighted avg       0.68      0.73      0.66      2110

# %%
plt.figure(figsize=(4,3))
sns.heatmap(confusion_matrix(y_test, lr_pred),
                annot=True,fmt = "d",linecolor="k",linewidths=3)
    
plt.title("LOGISTIC REGRESSION CONFUSION MATRIX",fontsize=14)
plt.show()

# %%
y_pred_prob = lr_model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot([0, 1], [0, 1], 'k--' )
plt.plot(fpr, tpr, label='Logistic Regression',color = "r")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logistic Regression ROC Curve',fontsize=16)
plt.show();

# %% [markdown]
# <a id = "105" ></a>
# #### **Decision Tree Classifier**
# <a id = "dtc" ></a>

# %%
# Membuat objek model Decision Tree
dt_model = DecisionTreeClassifier()

# Melatih model dengan data latih
dt_model.fit(X_train, y_train)

# Memprediksi target menggunakan data uji
predictdt_y = dt_model.predict(X_test)

# Menghitung akurasi model Decision Tree
accuracy_dt = dt_model.score(X_test, y_test)

# Menampilkan hasil akurasi
print("Decision Tree accuracy is:", accuracy_dt)
# Out:
# Decision Tree accuracy is: 0.6763033175355451

# %% [markdown]
# Decision tree gives very low score.

# %%
print(classification_report(y_test, predictdt_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78      1549
#            1       0.39      0.38      0.39       561
#
#     accuracy                           0.68      2110
#    macro avg       0.58      0.58      0.58      2110
# weighted avg       0.67      0.68      0.68      2110
